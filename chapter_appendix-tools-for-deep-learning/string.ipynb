# %%
string='Hello'
print(string)
# Out:
# Hello

# %%
# two types of indexing
# forward and positive index 
# reverse/negative indexing

# %% [markdown]
# 0,1,2,3,4...
# -1,-2,-3....

# %%
len(string)
# Out:
# 5

# %% [markdown]
# slicing[starting index: ending index ] it will not include the ending index element
# #var[lowest index: highest index]

# %%
string[1:4]
print(string)
string[-3:-1]
# Out:
# Hello
# 'll'

# %%
string[1:-3] 
# string can't be catentaion
# Out:
# 'e'

# %%
string1='abc'
string2='def'
print(string1+' '+string2)
# Out:
# abc def

# %%
print(string1+'4'+string2)
# Out:
# abc4def

# %%
algorithm='Neural Network'
print(algorithm)
len(algorithm)
# Out:
# Neural Network
# 14

# %%
algorithm.upper()
# Out:
# 'NEURAL NETWORK'

# %%
algorithm=algorithm.upper()

# %%
print(algorithm)
# Out:
# NEURAL NETWORK

# %%
algorithm.count("n")
# Out:
# 0

# %%
algorithm.count("N")
# Out:
# 2

# %%
algorithm.find('E')
# Out:
# 1

# %%
algorithm.find('e')
# Out:
# -1

# %% [markdown]
# list,Tuples,Set,Dict

# %%
w=23,"radhe",0,78+93j
w
# Out:
# (23, 'radhe', 0, (78+93j))

# %%
type(w)
# Out:
# tuple

# %% [markdown]
# LIst=[,,] mutable
# Tuple=(,,) immutable
# set={,,}
# dict={'key':'value'}
