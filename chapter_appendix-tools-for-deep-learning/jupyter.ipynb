# %%
print("H")
# Out:
# H

# %%
print("Jai Bhawani")
# Out:
# Jai Bhawani

# %%
print("Hello world")
# Out:
# Hello world

# %%
print("first")
_1_Data=78
_1_Data 
#no special characters are used for data variables name only we can use _ (underscore)
# Out:
# first
# 78

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
if(90>834):
    print("Yes")
else :
    print("NO")
# Out:
# NO

# %%
complex = 80 + 90j
complex
# Out:
# (80+90j)

# %%
list
tuple
dict

# %%
77/8
# Out:
# 9.625

# %%
77//8  #oNly integer part
# Out:
# 9

# %%
9**2
# Out:
# 81

# %%
3**-2
# Out:
# 0.1111111111111111

# %%
# and 
# or 
# not

# %%
y=90
y
# Out:
# 90

# %%
id(y) #it is memory address
# Out:
# 140712757232856

# %%
bin(id(y))
# Out:
# '0b11111111111101000111101111010010000010011011000'

# %%
hex(id(y))
# Out:
# '0x7ffa3de904d8'

# %%
oct(id(y))
# Out:
# '0o3777507572202330'

# %%
print("use \n to print a new line")
print("\n")
print("See what \n I mean")
# Out:
# use
#  to print a new line
#
#
# See what
#  I mean
